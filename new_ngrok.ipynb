# %%
# !pip install pyngrok
# !pip install flask_cors
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyngrok
#   Downloading pyngrok-5.1.0.tar.gz (745 kB)
#      |████████████████████████████████| 745 kB 15.2 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok) (6.0)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19007 sha256=3d6a933baf142a363c8d3a345c37e0be56b948a700a5d1161320bc18254a961e
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-5.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flask_cors
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.7/dist-packages (from flask_cors) (1.1.4)
# Requirement already satisfied: Six in /usr/local/lib/python3.7/dist-packages (from flask_cors) (1.15.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.9->flask_cors) (1.0.1)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.9->flask_cors) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.9->flask_cors) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.9->flask_cors) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.9->flask_cors) (2.0.1)
# Installing collected packages: flask-cors
# Successfully installed flask-cors-3.0.10

# %%
from flask import Flask
from pyngrok import ngrok

# %%
# app = Flask(__name__)
# ngrok.set_auth_token("2HMZEPEZjcXwPdOwSbgSdeofKJC_3tZ8UgTohqhQS9E3Td14g")
# public_url =  ngrok.connect(port_no).public_url

# @app.route("/")
# def home():
#     return f"Running Flask on Google Colab!"

# print(f"To acces the Gloable link please click {public_url}")

# app.run(port=port_no)

# %%
# ngrok.set_auth_token("2HMZEPEZjcXwPdOwSbgSdeofKJC_3tZ8UgTohqhQS9E3Td14g")
# public_url =  ngrok.connect(port_no).public_url
# print(f"To acces the Gloable link please click {public_url}")

# %%
# %cd /content/drive/MyDrive/final scoliosis/INFERNCE
# !python app.py
# Out:
# /content/drive/MyDrive/final scoliosis/INFERNCE

# %%
# !ls
# Out:
# 1.7.0	export.py   new_ngrok.ipynb   spine_inference.ipynb  train.py
# app.py	figure	    __pycache__       spine_inference.py     Untitled0.ipynb
# cfg	hubconf.py  requirements.txt  test.py		     utils
# data	inference   sample.py	      tools		     weights
# deploy	models	    scripts	      train_aux.py

# %%
# print(f"To acces the Gloable link please click {public_url}")

# %%
# !python app.py
# Out:
# YOLOR 🚀 2022-10-28 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# IDetect.fuse
# Model Summary: 208 layers, 6007596 parameters, 0 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# Updating authtoken for default "config_path" of "ngrok_path": /usr/local/lib/python3.7/dist-packages/pyngrok/bin/ngrok
# Opening tunnel named: http-5000-46016baf-ccd2-4aa0-9b2b-3350de31d798
# t=2022-11-12T06:30:01+0000 lvl=info msg="no configuration paths supplied"
# t=2022-11-12T06:30:01+0000 lvl=info msg="using configuration at default config path" path=/root/.ngrok2/ngrok.yml
# t=2022-11-12T06:30:01+0000 lvl=info msg="open config file" path=/root/.ngrok2/ngrok.yml err=nil
# t=2022-11-12T06:30:01+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040
# t=2022-11-12T06:30:02+0000 lvl=info msg="tunnel session started" obj=tunnels.session
# t=2022-11-12T06:30:02+0000 lvl=info msg="client session established" obj=csess id=03f811611be2
# t=2022-11-12T06:30:02+0000 lvl=info msg=start pg=/api/tunnels id=c05b7d5b8a353d8d
# t=2022-11-12T06:30:02+0000 lvl=info msg=end pg=/api/tunnels id=c05b7d5b8a353d8d status=200 dur=946.662µs
# t=2022-11-12T06:30:02+0000 lvl=info msg=start pg=/api/tunnels id=a86919d7ae2b801f
# t=2022-11-12T06:30:02+0000 lvl=info msg=end pg=/api/tunnels id=a86919d7ae2b801f status=200 dur=105.015µs
# t=2022-11-12T06:30:02+0000 lvl=info msg=start pg=/api/tunnels id=01d7ebf2ffa41031
# t=2022-11-12T06:30:02+0000 lvl=info msg="started tunnel" obj=tunnels name="http-5000-46016baf-ccd2-4aa0-9b2b-3350de31d798 (http)" addr=http://localhost:5000 url=http://6116-34-90-6-248.ngrok.io
# t=2022-11-12T06:30:02+0000 lvl=info msg="started tunnel" obj=tunnels name=http-5000-46016baf-ccd2-4aa0-9b2b-3350de31d798 addr=http://localhost:5000 url=https://6116-34-90-6-248.ngrok.io
# t=2022-11-12T06:30:02+0000 lvl=info msg=end pg=/api/tunnels id=01d7ebf2ffa41031 status=201 dur=226.498234ms
# t=2022-11-12T06:30:02+0000 lvl=info msg=start pg="/api/tunnels/http-5000-46016baf-ccd2-4aa0-9b2b-3350de31d798 (http)" id=fd15d1f6a4bac66e
# t=2022-11-12T06:30:02+0000 lvl=info msg=end pg="/api/tunnels/http-5000-46016baf-ccd2-4aa0-9b2b-3350de31d798 (http)" id=fd15d1f6a4bac66e status=200 dur=152.799µs
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# t=2022-11-12T06:31:15+0000 lvl=info msg="join connections" obj=join id=fa725a3df4c8 l=127.0.0.1:5000 r=112.134.75.67:16312
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#  The image with the result is saved in: inference/detected/28/28.jpg
# 127.0.0.1 - - [12/Nov/2022 06:31:22] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:31:51+0000 lvl=info msg="join connections" obj=join id=86ab1fb0c45d l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/4/4.jpg
# app.py:84: RuntimeWarning: invalid value encountered in double_scalars
#   cosine_angle_leftest = np.dot(l1, l2) / (np.linalg.norm(l1) * np.linalg.norm(l2))
# 127.0.0.1 - - [12/Nov/2022 06:31:53] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:32:09+0000 lvl=info msg="join connections" obj=join id=afcfc0b0ff99 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/5/5.jpg
# 127.0.0.1 - - [12/Nov/2022 06:32:13] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:33:01+0000 lvl=info msg="join connections" obj=join id=9e30e5d2bbc2 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/8/8.jpg
# 127.0.0.1 - - [12/Nov/2022 06:33:03] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:33:16+0000 lvl=info msg="join connections" obj=join id=d037a611ab7c l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/9/9.jpg
# 127.0.0.1 - - [12/Nov/2022 06:33:18] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:34:10+0000 lvl=info msg="join connections" obj=join id=3b047d35edae l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/10/10.jpg
# 127.0.0.1 - - [12/Nov/2022 06:34:12] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:35:05+0000 lvl=info msg="join connections" obj=join id=c64f94907683 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/11/11.jpg
# 127.0.0.1 - - [12/Nov/2022 06:35:06] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:35:30+0000 lvl=info msg="join connections" obj=join id=e25eb54f98b2 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/17/17.jpg
# app.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   cosine_angle_rightest = np.dot(l1, l2) / (np.linalg.norm(l1) * np.linalg.norm(l2))
# 127.0.0.1 - - [12/Nov/2022 06:35:31] "POST /scoliosis HTTP/1.1" 500 -
# t=2022-11-12T06:35:37+0000 lvl=info msg="join connections" obj=join id=84c7be3d154b l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/17/17.jpg
# 127.0.0.1 - - [12/Nov/2022 06:35:38] "POST /scoliosis HTTP/1.1" 500 -
# t=2022-11-12T06:35:59+0000 lvl=info msg="join connections" obj=join id=5791a9a87b48 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/20/20.jpg
# 127.0.0.1 - - [12/Nov/2022 06:36:00] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:36:46+0000 lvl=info msg="join connections" obj=join id=a7aec530d22c l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/21/21.JPG
# 127.0.0.1 - - [12/Nov/2022 06:36:46] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:37:04+0000 lvl=info msg="join connections" obj=join id=b6049e5a023f l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/23/23.jpg
# 127.0.0.1 - - [12/Nov/2022 06:37:09] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:37:32+0000 lvl=info msg="join connections" obj=join id=e8201a06ddae l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/24/24.jpg
# 127.0.0.1 - - [12/Nov/2022 06:37:32] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:41:21+0000 lvl=info msg="join connections" obj=join id=8d34a68cf481 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/N2NF17_1_0/N2NF17_1_0.jpg
# 127.0.0.1 - - [12/Nov/2022 06:41:22] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:42:52+0000 lvl=info msg="join connections" obj=join id=57504ac2cd4f l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/N6N17M_1_0/N6N17M_1_0.jpg
# 127.0.0.1 - - [12/Nov/2022 06:42:52] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:43:47+0000 lvl=info msg="join connections" obj=join id=0d8cf110ad1f l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/N5NF31_1_0/N5NF31_1_0.jpg
# 127.0.0.1 - - [12/Nov/2022 06:43:48] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:44:14+0000 lvl=info msg="join connections" obj=join id=17e944f2dca8 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/N7NM8_1_0/N7NM8_1_0.jpg
# 127.0.0.1 - - [12/Nov/2022 06:44:14] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:45:18+0000 lvl=info msg="join connections" obj=join id=a65c5e771664 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/N6NF15_1_0/N6NF15_1_0.jpg
# 127.0.0.1 - - [12/Nov/2022 06:45:19] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:45:44+0000 lvl=info msg="join connections" obj=join id=4c4e971e599a l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/N23NF29_1_0/N23NF29_1_0.jpg
# 127.0.0.1 - - [12/Nov/2022 06:45:45] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:45:55+0000 lvl=info msg="join connections" obj=join id=8ceda8a1c8f4 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/N9NF13_1_0/N9NF13_1_0.jpg
# 127.0.0.1 - - [12/Nov/2022 06:45:56] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:46:19+0000 lvl=info msg="join connections" obj=join id=a1bc9eeb0e78 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/31/31.jpg
# 127.0.0.1 - - [12/Nov/2022 06:46:20] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:56:16+0000 lvl=info msg="join connections" obj=join id=802bff826cdd l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/31/31.jpg
# 127.0.0.1 - - [12/Nov/2022 06:56:17] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:56:51+0000 lvl=info msg="join connections" obj=join id=f0c8921b460f l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/32/32.jpg
# 127.0.0.1 - - [12/Nov/2022 06:56:52] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:57:07+0000 lvl=info msg="join connections" obj=join id=607ed5b915d2 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/33/33.jpg
# 127.0.0.1 - - [12/Nov/2022 06:57:08] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:57:19+0000 lvl=info msg="join connections" obj=join id=85a24ab7511f l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/34/34.jpg
# 127.0.0.1 - - [12/Nov/2022 06:57:19] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:57:40+0000 lvl=info msg="join connections" obj=join id=dd8743c53d50 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/35/35.jpg
# 127.0.0.1 - - [12/Nov/2022 06:57:43] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:58:00+0000 lvl=info msg="join connections" obj=join id=a1c88efc511c l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/36/36.jpg
# 127.0.0.1 - - [12/Nov/2022 06:58:02] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:58:15+0000 lvl=info msg="join connections" obj=join id=637fad4816bd l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/37/37.jpg
# 127.0.0.1 - - [12/Nov/2022 06:58:17] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:58:29+0000 lvl=info msg="join connections" obj=join id=a2558793f85b l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/38/38.jpg
# 127.0.0.1 - - [12/Nov/2022 06:58:30] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:58:51+0000 lvl=info msg="join connections" obj=join id=ee5210507107 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/40/40.jpg
# 127.0.0.1 - - [12/Nov/2022 06:58:51] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:59:09+0000 lvl=info msg="join connections" obj=join id=e34b9731b840 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/41/41.jpg
# 127.0.0.1 - - [12/Nov/2022 06:59:10] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:59:23+0000 lvl=info msg="join connections" obj=join id=fbe03aa9e0b6 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/43/43.jpg
# 127.0.0.1 - - [12/Nov/2022 06:59:24] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:59:35+0000 lvl=info msg="join connections" obj=join id=a17bfb3efd2e l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/45/45.jpg
# 127.0.0.1 - - [12/Nov/2022 06:59:37] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T06:59:48+0000 lvl=info msg="join connections" obj=join id=88b3f3ad447e l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/50/50.jpg
# 127.0.0.1 - - [12/Nov/2022 06:59:49] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:00:10+0000 lvl=info msg="join connections" obj=join id=93b42c561f1c l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/71/71.jpg
# 127.0.0.1 - - [12/Nov/2022 07:00:12] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:00:17+0000 lvl=info msg="join connections" obj=join id=002076931b51 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/71/71.jpg
# 127.0.0.1 - - [12/Nov/2022 07:00:19] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:00:30+0000 lvl=info msg="join connections" obj=join id=8b8df27ded52 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/67/67.jpg
# 127.0.0.1 - - [12/Nov/2022 07:00:32] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:03:33+0000 lvl=info msg="join connections" obj=join id=ce6f8a67f7f9 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/129/129.jpg
# 127.0.0.1 - - [12/Nov/2022 07:03:44] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:03:53+0000 lvl=info msg="join connections" obj=join id=58ac21758724 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/129/129.jpg
# 127.0.0.1 - - [12/Nov/2022 07:04:04] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:04:17+0000 lvl=info msg="join connections" obj=join id=e811e958e431 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/132/132.jpg
# 127.0.0.1 - - [12/Nov/2022 07:04:28] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:04:45+0000 lvl=info msg="join connections" obj=join id=9b7a1bb23f88 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/139/139.jpg
# 127.0.0.1 - - [12/Nov/2022 07:04:52] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:05:05+0000 lvl=info msg="join connections" obj=join id=6b3163d0a28f l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/133/133.jpg
# 127.0.0.1 - - [12/Nov/2022 07:05:15] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:05:30+0000 lvl=info msg="join connections" obj=join id=a0e69fe67d6e l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/138/138.jpg
# 127.0.0.1 - - [12/Nov/2022 07:05:40] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:06:03+0000 lvl=info msg="join connections" obj=join id=065008e662c8 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/143/143.jpg
# 127.0.0.1 - - [12/Nov/2022 07:06:07] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:06:24+0000 lvl=info msg="join connections" obj=join id=35c974fcbae0 l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/153/153.jpg
# 127.0.0.1 - - [12/Nov/2022 07:06:32] "POST /scoliosis HTTP/1.1" 200 -
# t=2022-11-12T07:06:50+0000 lvl=info msg="join connections" obj=join id=8dde9701630f l=127.0.0.1:5000 r=112.134.75.67:16312
#  The image with the result is saved in: inference/detected/150/150.jpg
# 127.0.0.1 - - [12/Nov/2022 07:07:04] "POST /scoliosis HTTP/1.1" 200 -
